# %%
import pandas as pd
df=pd.read_csv('student_logins.csv')

# %%
a = df.ix[:,0]
b = df.ix[:,1]
a = pd.to_datetime(a)
b = pd.to_datetime(b)
c = b - a

# %%
df['timdelta'] = c
df = df[df.timdelta !=0]
df = df[df.student_id !=342]
df = df[df.student_id !=297]
df = df[df.student_id !=172]

# %%
df.head()
# Out:
#   session_start_time session_end_time class_id  problems_completed  \
# 0       1/6/12 16:28     1/6/12 16:55        e                  37
# 1       1/7/12 11:00     1/7/12 11:27        e                  24
# 2        1/8/12 9:04      1/8/12 9:31        e                  50
# 3       1/9/12 12:41     1/9/12 12:48        e                  26
# 4       1/9/12 16:59     1/9/12 17:43        m                  37
#
#    student_id student_account_created  student_previous_logins_total  \
# 0          91           10/26/11 0:00                             76
# 1         161             1/6/12 0:00                              2
# 2         141           12/31/11 0:00                              8
# 3         101           11/16/11 0:00                            199
# 4         103           11/23/11 0:00                            100
#
#    student_previous_class_logins  timdelta
# 0                             27  00:27:00
# 1                              0  00:27:00
# 2                              5  00:27:00
# 3                            104  00:07:00
# 4                             41  00:44:00

# %%
X = df['problems_completed']
X = sm.add_constant(X, prepend=True)
y = df['timdelta']

# %%
import numpy as np
y = y / np.timedelta64(1, 's')

# %%
# Statsmodel APIs
# %matplotlib inline
import statsmodels.api as sm
from matplotlib import pyplot as plt
results = sm.OLS(y, X).fit()
intercept,slope = results.params

r2 = results.rsquared

plt.plot(X, y, 'bo')
plt.title("Price vs Sqft")
xl = X
yl = intercept + slope * xl
plt.plot(xl, yl, 'r-')
plt.show
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               timdelta   R-squared:                       0.413
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                 3.265e+04
# Date:                Sun, 26 Oct 2014   Prob (F-statistic):               0.00
# Time:                        15:13:23   Log-Likelihood:            -3.7676e+05
# No. Observations:               46502   AIC:                         7.535e+05
# Df Residuals:                   46500   BIC:                         7.535e+05
# Df Model:                           1
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# const                375.4094      6.899     54.417      0.000       361.888   388.931
# problems_completed    61.8645      0.342    180.697      0.000        61.193    62.536
# ==============================================================================
# Omnibus:                    20004.057   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           166441.901
# Skew:                           1.868   Prob(JB):                         0.00
# Kurtosis:                      11.482   Cond. No.                         37.6
# ==============================================================================
# """
